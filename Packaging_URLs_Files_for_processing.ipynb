# %% [markdown]
# <a href="https://colab.research.google.com/github/skybristol/experiments/blob/dev/Packaging_URLs_Files_for_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# One of the design patterns for a standard service we are exploring is where we need to fetch data from some online location where a file is available via a URL, put those files into a cloud bucket, and then kick off various types of transformation processing. In one use case, we are pulling files linked to from an inventory page for a USGS time-series data set put out as a periodic "Data Series Report." We want to get these data into a combined format with an API for working with the data more effectively than regularly stitching together individual files.
#
# This notebook looks at how to read in the web page where the files are linked and prepare messages for a message queue process that will kick off file retrieval over HTTP onto S3 and then launch subsequent processing. In this and many cases, we will need to assemble some context from the way that the files are distributed into metadata about the files that can be used to drive specific processing. Often in these cases, we will be dealing with file contents that are not individually described in a way that is sufficient to understand and work with them effectively. These are essentially cases where data are treated as "ancillary files" to a publication or web page as opposed to being thoroughly documented and served through a data repository. We're trying to get away from this practice, but it is still all too common and we need some way of dealing with that into further processing.

# %%
import requests
from bs4 import BeautifulSoup

# %%
ds140_url = "https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states"
r = requests.get(ds140_url)
page_content = BeautifulSoup(r.text, 'html.parser')

# %% [markdown]
# This is where we essentially need to apply some customized logic for every case like this to create a metadata structure with whatever information we can derive from the context and/or the source content. We will want to hone this and standardize it as much as possible, potentially working to align the structure with some appropriate metadata standard. In the near term, I'm working on just coming up with the information that could be used to generate a set of messages for a message queue that would kick off processing. We need to develop enough context around each file we identify behind URLs on the subject source page that subsequent processes know how to operate and what information to pass along.

# %%
inventory = list()

for row in page_content.find_all("table")[1].find_all("tr")[2:]:
    columns = row.find_all("td")
    commodity_name = columns[0].text.strip().replace("\xa0", " ")
    if columns[2].text.strip().lower() in ["xlsx","xls"]:
        inventory.append({
            "commodity": commodity_name,
            "data_source": "DS140",
            "data_source_url": "https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states",
            "file_source_extraction_function": "<resolvable reference to function that generated this message>",
            "data_type": "Supply-Demand Statistics",
            "update_year": columns[3].text.strip(),
            "file_url": columns[2].find("a")["href"],
            "next_actions": [
                "Extract Worksheets as CSV Tables",
                "Extract Word Documents"
            ]
        })

    if len(columns) >= 6 and columns[5].text.strip().lower() in ["xlsx","xls"]:
        inventory.append({
            "commodity": commodity_name,
            "data_source": "DS140",
            "data_source_url": "https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states",
            "file_source_extraction_function": "<resolvable reference to function that generated this message>",
            "data_type": "End-Use Statistics",
            "update_year": columns[-1].text.strip(),
            "file_url": columns[5].find("a")["href"],
            "next_actions": [
                "Extract Worksheets as CSV Tables"
            ]
        })

    if len(columns) == 5 and columns[3].text.strip().lower() in ["xlsx","xls"]:
        inventory.append({
            "commodity": commodity_name,
            "data_source": "DS140",
            "data_source_url": "https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states",
            "file_source_extraction_function": "<resolvable reference to function that generated this message>",
            "data_type": "End-Use Statistics",
            "update_year": columns[-1].text.strip(),
            "file_url": columns[3].find("a")["href"],
            "next_actions": [
                "Extract Worksheets as CSV Tables"
            ]
        })

# %% [markdown]
# The resulting dictionaries here should be relatively simple and straightforward. Here is a basic explanation of each property we've assembled and why it is important to the next steps.
#
# * commodity - commodity names (minerals and other materials) are the key organizing identifier that will be used in our system. These will ultimately need to be aligned with a source of definition and a resolvable identifier from larger vocabulary work, but we do a little cleanup here on how they are listed in this venue.
# * data_source - simple referral point to how this data source is often used in common language
# * data_source_url - it's important to keep track of what was processed to get the references we are sending on for further processing
# * file_source_extraction_function - this is a placeholder for some type of resolvable reference that points to the Lambda code or some executable that did the work against the data_source_url to get files for processing
# * file_url - the URL where a file that we want to fetch into further processing can be obtained
# * next_actions - text strings here should probably be replaced with some kind of resolvable identifier for subsequent processes (executed as lambdas or whatever) that are going to be kicked off after the files are fetched onto cloud storage; in this case we are saying that all files need to have CSV tables extracted and some also need to be checked for embedded Word documents and have those pulled out
# * update_year - this is the key piece of information that indicates when a given commodity statistics file was updated, we may need to count on this as an indicator of when a file should be re-fetched for re-processing as the file URL and other information may not be sufficient
#
# Note on file naming: It might be reasonable to use a hash of the file_url value as a file name/prefix here as opposed to what will be variable source file names. This would help us connect dots with an opaque unique identifier back to metadata from this process. In running subsequent extraction processes to do things like pull out CSV tables where we might have multiple CSV files per Excel file, we could use a combination of the hashed file_url with worksheet name or index position to uniquely name those derived files.

# %%
inventory
# Out:
# [{'commodity': 'Abrasives (manufactured)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-abras.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Abrasives (natural)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-abran.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2014'},
#  {'commodity': 'Aluminum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-alumi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Aluminum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/aluminum-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Agriculture and Fishery',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-agric.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Antimony',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-antim.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Antimony',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/antimony-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Arsenic',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-arsen.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Arsenic',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/arsenic-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Asbestos',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-asbes.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Asbestos',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/asbestos-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Barite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-barit.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Bauxite and alumina',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-bauxi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Bauxite and alumina',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/bauxite-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Beryllium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-beryl.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Beryllium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/beryllium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Bismuth',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-bismu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Bismuth',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/bismuth-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Boron',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-boron.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Boron',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/boron-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Bromine',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-bromi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Cadmium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-cadmi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Cadmium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/cadmium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Cement',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-cemen.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Cement',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/cement-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Cesium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-cesiu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Chromium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-chrom.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Chromium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/chromium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Clays',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-clays.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Ball clay',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/claysball-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Bentonite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/claysbentonite-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Fire clay',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/claysfire-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': "Fuller's earth",
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/claysfullers-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Kaolin',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/clayskaolin-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Miscellaneous clay and shale',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/claysmisc-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Coal combustion products',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-coal.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': 'NA'},
#  {'commodity': 'Cobalt',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-cobal.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Cobalt',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/cobalt-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Copper',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-coppe.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Copper',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/copper-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Diamond (industrial)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-diamo.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Diamond (industrial)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/diamondindustrial-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Diatomite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-diato.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Diatomite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/diatomite-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Feldspar',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-felds.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Feldspar',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/feldspar-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Fluorspar',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-fluor.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Fluorspar',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/fluorspar-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Gallium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-galli.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Gallium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/gallium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Garnet (industrial)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-garne.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Garnet (industrial)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/garnet-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Gemstones',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-gemst.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Germanium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-germa.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Germanium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/germanium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Gold',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-gold.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Gold',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/gold-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Graphite (natural)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-graph.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Graphite (natural)',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/graphite-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Gypsum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-gypsu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Gypsum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/gypsum-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Hafnium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-hafni.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Helium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-heliu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Helium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/helium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Indium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-indiu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Indium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/indium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Iodine',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-iodin.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Iron and steel',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-feste.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Iron and steel',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ironsteel-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Iron and steel scrap',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-fescr.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Iron and steel slag',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-fesla.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Iron and steel slag',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ironsteelslag-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Iron ore',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-feore.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Iron ore',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ironore-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Iron oxide pigments',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-fepig.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Iron oxide pigments',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ironoxide-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Kyanite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-kyani.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Lead',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-lead.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Lead',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/lead-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Lime',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-lime.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Lime',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/lime-use_2.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Lithium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-lithi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Magnesium compounds',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-mgcom.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Magnesium compounds',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/magnesiumcompounds-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Magnesium metal',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-mgmet.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Magnesium metal',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/magnesium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Manganese',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
# ...
#   'update_year': '2003'},
#  {'commodity': 'Strontium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-stron.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Strontium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/strontium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Sulfur',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-sulfu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Sulfur',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/sulfur-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Talc and pyrophyllite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-talc.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Talc and pyrophyllite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/talc-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Tantalum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-tanta.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tantalum',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/tantalum-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Tellurium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-tellu.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tellurium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/tellurium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Thallium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-thall.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Thorium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-thori.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tin',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-tin.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tin',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/tin-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Titanium dioxide pigment',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-tipig.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Titanium dioxide pigment',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/titaniumdioxide-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2004'},
#  {'commodity': 'Titanium metal',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-timet.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Titanium metal',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/titanium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2004'},
#  {'commodity': 'Titanium mineral concentrates',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-timin.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tungsten',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-tungs.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Tungsten',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/tungsten-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Vanadium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-vanad.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Vanadium',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/vanadium-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Vermiculite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-vermi.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Wollastonite',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2018-wolla.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2018'},
#  {'commodity': 'Wood',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://s3-us-west-2.amazonaws.com/prd-wret/assets/palladium/production/mineral-pubs/historical-statistics/ds140-wood.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2015'},
#  {'commodity': 'Zinc',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-zinc.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'},
#  {'commodity': 'Zinc',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'End-Use Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3-us-west-2.amazonaws.com/assets/palladium/production/atoms/files/zinc-use.xls',
#   'next_actions': ['Extract Worksheets as CSV Tables'],
#   'update_year': '2003'},
#  {'commodity': 'Zirconium mineral concentrates',
#   'data_source': 'DS140',
#   'data_source_url': 'https://www.usgs.gov/centers/nmic/historical-statistics-mineral-and-material-commodities-united-states',
#   'data_type': 'Supply-Demand Statistics',
#   'file_source_extraction_function': '<resolvable reference to function that generated this message>',
#   'file_url': 'https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/atoms/files/ds140-2017-zirco.xlsx',
#   'next_actions': ['Extract Worksheets as CSV Tables',
#    'Extract Word Documents'],
#   'update_year': '2017'}]
